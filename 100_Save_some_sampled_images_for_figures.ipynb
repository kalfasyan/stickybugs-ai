# %%
# %reset -f
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config Completer.use_jedi = False

# %%
from datasets import InsectImgDataset
from utils import *
import pandas as pd
from pathlib import Path
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import matplotlib.pyplot as plt

setting = 'fuji'
if setting == 'photobox':
    ext = '.png'
elif setting == 'fuji':
    ext = '.jpg'

# %%
dfs = InsectImgDataset(directory=DATA_DIR, ext=ext, setting=setting)
dfs.extract_df_info()
df = dfs.df
# Out:
# Extracting info from filenames..: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 72475/72475 [00:08<00:00, 8294.07it/s]

# %%
df = df[df.year=='2021']

# %%
import os

for i,sub in dfs.df.groupby('label'):
    p = f"/home/kalfasyan/Dropbox/worklaptop_results/{sub.label.unique()[0]}/"
    if not os.path.isdir(p):
        os.makedirs(p)
    copy_files(sub.sample(10, replace=True).filename.tolist(), f"/home/kalfasyan/Dropbox/worklaptop_results/{sub.label.unique()[0]}/")
# Out:
# ...
# Copying files..: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21.07it/s]

# %%
print(f"/home/kalfasyan/Dropbox/worklaptop_results/{sub.label.unique()[0]}")
# Out:
# /home/kalfasyan/Dropbox/worklaptop_results/ONBEKEND

# %%
# Out:
# 'ONBEKEND'
